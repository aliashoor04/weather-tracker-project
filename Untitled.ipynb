# %%
def main():
    while True:
        print("\n--- Weather Tracker ---")
        print("1. Record new weather observation")
        print("2. View weather statistics")
        print("3. Search observations by date")
        print("4. View all observations")
        print("5. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            print("Add observation")
        elif choice == "2":
            print("View statistics")
        elif choice == "3":
            print("Search by date")
        elif choice == "4":
            print("View all")
        elif choice == "5":
            print("Goodbye")
            break
        else:
            print("Invalid choice")

main()
# Out:
# ---Weather Tracker---
# 1. Record new weather observation
# 2. View weather statistics
# 3. Search observations by date
# 4. View all observations
# 5. Exit
